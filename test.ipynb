# %%
# !pip install PublicDataReader --upgrade
# 한번만 실행하고 주석처리

import pandas as pd
pd.options.display.max_rows = 30
pd.options.display.max_columns = 100

import warnings, time
warnings.filterwarnings(action='ignore')
# warning을 무시하는 코드

import PublicDataReader as pdr
code_df = pdr.code_bdong()
code_df
# 법정동 코드를 불러오는 방법입니다.
# 서버에서 데이터를 불러왔다고 이해해주시면 됩니다.

# %%
import requests, json
import time

# 개발자도구에서 확인한 정확한 헤더 사용
headers = {
    'accept': 'application/json',
    'accept-encoding': 'gzip, deflate, br, zstd',
    'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
    'cache-control': 'no-cache',
    'pragma': 'no-cache',
    'priority': 'u=1, i',
    'referer': 'https://hogangnono.com/apt/eiw54',
    'sec-ch-ua': '"Chromium";v="140", "Not=A?Brand";v="24", "Google Chrome";v="140"',
    'sec-ch-ua-mobile': '?1',
    'sec-ch-ua-platform': '"Android"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/140.0.0.0 Mobile Safari/537.36',
    # 필수 커스텀 헤더들
    'x-hogangnono-api-version': '2.2.0',
    'x-hogangnono-app-name': 'hogangnono',
    'x-hogangnono-platform': 'desktop',
    'x-hogangnono-release-version': '2.2.0.3'
}

# 현재 시간 기반 타임스탬프 생성
current_time = int(time.time() * 1000)
headers['x-hogangnono-ct'] = str(current_time)

# 쿠키 설정
cookies = {
    'bat': 'B-CcjuQR4gIqL1-ClqPXDw0VpKlEZ01QgDzg',
    '_wp_uid': '1-322167f419ec368e16b3f39e217a285f-s1727949261.962439|mac_osx|chrome-10vi4jy',
    '_fbp': 'fb.1.1758075053753.474686016959697018',
    '_gcl_au': '1.1.149389477.1758075054',
    'connect.sid': 's%3AtAhJONi05PXjPG-o20yLugz_oeclMwT2vg.OVPlDTozvsFdOYxGxENMWt0LjJv%2BjfIEl2dxNcDA398',
    'client.cid': 'OVPlDTozvsFdOYxGxENMWt0LjJv%2BjfIEl2dxNcDA398',
    '_ga': 'GA1.2.1373535246.1740832985',
    '_gid': 'GA1.2.756130704.1758711109'
}

url = "https://hogangnono.com/api/v2/pois-bounding?level=17&startX=126.8464167&endX=126.8577678&startY=37.4712578&endY=37.4762134&apt=eiw54&isIgnorePin=false"

try:
    req = requests.get(url, headers=headers, cookies=cookies, timeout=10)
    
    print(f"HTTP 상태 코드: {req.status_code}")
    print(f"요청 URL: {req.url}")
    
    if req.status_code == 200:
        try:
            data1 = json.loads(req.text)
            
            if data1.get('status') == 'success':
                print("✅ 데이터 로드 성공!")
                print(f"�� 데이터 개수: {len(data1.get('data', []))}")
                
                # data1 값 확인
                print("=== data1 전체 데이터 ===")
                print(data1)
                
            else:
                print("❌ API 응답에서 오류 발생:")
                print(data1)
                
        except json.JSONDecodeError as e:
            print(f"❌ JSON 파싱 오류: {e}")
            print(f"📄 원본 응답: {req.text[:500]}...")
            
    else:
        print(f"❌ HTTP 오류: {req.status_code}")
        print(f"📄 응답 내용: {req.text}")
        
except requests.RequestException as e:
    print(f"❌ 요청 오류: {e}")
except Exception as e:
    print(f"❌ 예상치 못한 오류: {e}")
# Out:
# HTTP 상태 코드: 200
# 요청 URL: https://hogangnono.com/api/v2/pois-bounding?level=17&startX=126.8464167&endX=126.8577678&startY=37.4712578&endY=37.4762134&apt=eiw54&isIgnorePin=false
# ✅ 데이터 로드 성공!
# �� 데이터 개수: 15
# === data1 전체 데이터 ===
# ...
